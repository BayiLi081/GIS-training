# %% [markdown]
# <div align="center"><img src="./images/LKYCIC_Header.jpg"></div>

# %% [markdown]
# # Fundamentals of Geospatial Data Science with Python

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this workshop you will use Python, a programming language enabling data science, to help stave off a simulated epidemic affecting the entire UK population, using population-scale data. In service of this goal, this workshop is divided into 3 sections:
#
# - *Geospatial Data Acquiring and Manipulation*
# - *Geospatial Data Analysis and Visualisation*
# - *Project: Biodefense*

# %% [markdown]
# ## Preparation
#
# **[0-01_intro.ipynb](./0-01_intro.ipynb)**: This notebook.
#
# **[0-02_environment.ipynb](./0-02_environment.ipynb)**: Learn your interactive coding environment.

# %% [markdown]
# ## Geospatial Data Acquiring and Manipulation
#
# In this section you will learn how to use **Geemap** to acquire several geospatial data sets, including population data, road network data, and satellite imagery. You will also learn how to access the data in specific regions of interest and transform the data into a format that can be used for further analysis.

# %% [markdown]
# ## Table of Contents
#
# **[1-01_geemap.ipynb](./1-01_geemap.ipynb)**: Begin learning GPU-accelerated dataframe manipulation with cuDF.
#
# **[1-02_pandas_basics.ipynb](./1-02_pandas_basics.ipynb)**: Begin learning GPU-accelerated dataframe manipulation with cuDF.
#
# **[1-03_grouping_sorting.ipynb](./1-03_grouping_sorting.ipynb)**: Learn more advanced cuDF operations.
#
# **[1-04_gpd_basics.ipynb](./1-04_gpd_basics.ipynb)**: Advance your cuDF skills and use CuPy to apply fast user-defined functions, prepping datasets for machine learning.

# %% [markdown]
# ## Geospatial Data Analysis and Visualisation
#
# In this section you will learn how to use **GeoPandas** to xxxx, **Seaborn** to xxx, and **Folium** to xxx.

# %% [markdown]
# ## Table of Contents
#
# **[2-01_spatial_statistics.ipynb](./2-01_spatial_statistics.ipynb)**: Use cuDF to prepare data for graph analytics.
#
# **[2-02_seaborn.ipynb](./2-02_seaborn.ipynb)**: Use cuDF to prepare data for graph analytics.
#
# **[2-03_folium.ipynb](./2-03_folium.ipynb)**: Use cuDF to prepare data for graph analytics.

# %% [markdown]
# ## Project: Biodefense

# %% [markdown]
# ## Table of Contents
#
# **[3-01_spatial_statistics.ipynb](./2-01_spatial_statistics.ipynb)**: Use cuDF to prepare data for graph analytics.
#
# **[3-01_spatial_statistics.ipynb](./2-01_spatial_statistics.ipynb)**: Use cuDF to prepare data for graph analytics.
#
# **[3-01_spatial_statistics.ipynb](./2-01_spatial_statistics.ipynb)**: Use cuDF to prepare data for graph analytics.

# %%
## Next

Please proceed to the [next notebook](1-02_environment.ipynb).
