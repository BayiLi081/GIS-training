# %% [markdown]
# <div align="center"><img src="./images/LKYCIC_Header.jpg"></div>

# %% [markdown]
# # Jupyter Notebook and Google Colab

# %% [markdown]
# ## Jupyter Notebook
# Jupyter Notebook is a **web-based interactive** Python computing environment. Jupyter Notebook allows users to **integrate code, text, equations, and visualizations in a single document** known as a “notebook.”

# %%
print("Hello World")
# Out:
# Hello World

# %%
input("what is going on?")
# Out:
# what is going on? nothing going on
# 'nothing going on'

# %% [markdown]
# Assign the keyboard input as a variable

# %%
msg = input("what is going on?")
# Out:
# what is going on? nothing going on

# %% [markdown]
# Print the question with variable

# %%
print("what is going on?", msg)
# Out:
# what is going on? nothing going on

# %% [markdown]
# Install package in cells of Jupyter Notebook.
#
# Because in Jupyter Notebook, you are interacting with Python; when you wish to install some packages, you need to interact with terminal. Therefore, we are using some magic command to let Jupyter knows you are trying to run the command from terminal. In this case, the code to run is
#
# %pip install pandas

# %%
# %ls -f
# Out:
# ./                            2-01_spatial_statistics.ipynb*
# ../                           2-02_gpd_readfiles.ipynb*
# .git/                         2-02_seaborn.ipynb*
# .ipynb_checkpoints/           2-03_folium.ipynb*
# 0-01_intro.ipynb*             640.webp*
# 0-02_environment.ipynb*       data/
# 1-01_geemap.ipynb*            GIS-training.code-workspace*
# 1-02_pandas_basics.ipynb*     images/
# 1-03_grouping_sorting.ipynb*  README.md*
# 2-01_gpd_basics.ipynb*

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# as means "alias"
#
# It is more out of using habits to give an alias to a longname package. Therefore, you can use pd to represent pandas in the following scripts. Similarly, np is numpy, gpd is geopandas.
#
# **Can you install numpy and import it as np here?**

# %% [markdown]
# ## Google Colab
#
# Colab notebooks are **Jupyter notebooks that are hosted by Colab**.
#
# There are some advantages of using Google Colab:
#
#
#
# References: https://www.geeksforgeeks.org/google-collab-vs-jupyter-notebook/
