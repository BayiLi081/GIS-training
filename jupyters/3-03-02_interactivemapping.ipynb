# %% [markdown]
# <div align="center"><img src="../images/LKYCIC_Header.jpg"></div>

# %% [markdown]
# # 3-03-02: Interactive Mapping

# %%
import folium
import pandas as pd
import geopandas as gpd

# %%
# Load the data
data_gdf = gpd.read_file("../data/raw/part_iii/HCMC_Metro/planned_metro.shp")

data_gdf.head()

# %%
m = folium.Map((10.82, 106.62), tiles="cartodb positron", zoom_start=12)

popup = folium.GeoJsonPopup(
    fields=["Name", "metro"],
    aliases=["Name", "Metro"],
    labels=True, # show field names as labels
    style="background-color: black;", # white background
    lazy=True, # bind on click
)

g = folium.GeoJson(
    data_gdf,
    style_function=lambda x: {
        "fillColor": "red",
        "color": "black",
        "fillOpacity": 0.4,
    },
    popup=popup,
).add_to(m)

m

# %%
def getHTML(row):
   return "<b> This Metro Station belongs to: %s </b>" % row["metro"]

data_gdf["html"] = data_gdf.apply(getHTML, axis=1)

# %%
data_gdf.head()

# %%
m = folium.Map((10.82, 106.62), tiles="cartodb positron", zoom_start=12)

popup = folium.GeoJsonPopup(
    labels= False, fields = ["html"], # show the pre-defined html content as a popup
    style="background-color: yellow;",
)

g = folium.GeoJson(
    data_gdf,
    style_function=lambda x: {
        "fillColor": "red",
        "color": "black",
        "fillOpacity": 0.4,
    },
    popup=popup,
).add_to(m)

m

# %%
icon_customise = folium.CircleMarker(radius = 10, # Radius in metres
                                           weight = 0, #outline weight
                                           fill_color = '#227bc9', 
                                           fill_opacity = 1)

m = folium.Map((10.82, 106.62), tiles="cartodb positron", zoom_start=12)

popup = folium.GeoJsonPopup(
    labels= False, fields = ["html"],
    localize=True,
    style="background-color: yellow;",
)

g = folium.GeoJson(
    data_gdf,
    popup=popup,
    marker=icon_customise,
    name="Metro Stations",
).add_to(m)

folium.LayerControl().add_to(m)

m

# %%
data_gdf['metro'].unique()

# %%
# Assigning unique hex colour codes
metro_line_colours = {
    'Line 3A': '#FF5733',  # Example colours
    'LA': '#33FF57',
    'Line 2': '#5733FF',
    'Line 3B': '#33FFF5',
    'Line 4': '#F5FF33',
    'Line 5': '#FF33A1',
    'Line 6': '#A133FF',
    'Tramway 1': '#33FFA1',
    'Monorail 2': '#A1FF33',
    'Monorail 3': '#FFC733',
    'Regional': '#3375FF'
}

# %%
# Create a map
m = folium.Map((10.82, 106.62), tiles="cartodb positron", zoom_start=12)

# Iterate through each metro line
for metro in metro_line_colours.keys():
    # Create a FeatureGroup for the metro line
    metro_layer = folium.FeatureGroup(name=f"{metro} Line", show=True)
    
    # Filter data for the current metro line
    metro_line_data = data_gdf[data_gdf['metro'] == metro]
    
    # Iterate through each row in the filtered data
    for _, row in metro_line_data.iterrows():
        # Extract station coordinates (assuming Point geometry)
        coords = [row.geometry.y, row.geometry.x]
        
        # Add CircleMarker for each station to the metro layer
        folium.CircleMarker(
            location=coords,
            radius=10,  # Radius in pixels
            weight=1,  # Outline weight
            color=metro_line_colours[metro],  # Outline colour
            fill_color=metro_line_colours[metro],  # Fill colour
            fill_opacity=0.5,
            popup=folium.Popup(row['html'], max_width=300)  # Use 'html' field for popup
        ).add_to(metro_layer)
    
    # Add the metro line layer to the map
    metro_layer.add_to(m)

# Add a LayerControl to toggle layers on/off
folium.LayerControl().add_to(m)

# Display the map
m

# %%
# save the map
m.save("../output/html/map.html")

# %% [markdown]
# You can deploy the html to your server.
#
# In this time, we deploy it on GitHub.
#
# The url to the webpage is https://spatialuminous.top/GIS-training/map.html.

# %% [markdown]
# ## Chorepleth Map

# %%
import pandas as pd

url = (
    "https://raw.githubusercontent.com/python-visualization/folium/main/examples/data"
)
state_geo = f"{url}/us-states.json"
state_unemployment = f"{url}/US_Unemployment_Oct2012.csv"
state_data = pd.read_csv(state_unemployment)

# %%
state_geo
# Out:
# 'https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/us-states.json'

# %%
state_data
# Out:
#    State  Unemployment
# 0     AL           7.1
# 1     AK           6.8
# 2     AZ           8.1
# 3     AR           7.2
# 4     CA          10.1
# 5     CO           7.7
# 6     CT           8.4
# 7     DE           7.1
# 8     FL           8.2
# 9     GA           8.8
# 10    HI           5.4
# 11    ID           6.6
# 12    IL           8.8
# 13    IN           8.4
# 14    IA           5.1
# 15    KS           5.6
# 16    KY           8.1
# 17    LA           5.9
# 18    ME           7.2
# 19    MD           6.8
# 20    MA           6.7
# 21    MI           9.1
# 22    MN           5.6
# 23    MS           9.1
# 24    MO           6.7
# 25    MT           5.8
# 26    NE           3.9
# 27    NV          10.3
# 28    NH           5.7
# 29    NJ           9.6
# 30    NM           6.8
# 31    NY           8.4
# 32    NC           9.4
# 33    ND           3.2
# 34    OH           6.9
# 35    OK           5.2
# 36    OR           8.5
# 37    PA           8.0
# 38    RI          10.1
# 39    SC           8.8
# 40    SD           4.4
# 41    TN           7.8
# 42    TX           6.4
# 43    UT           5.5
# 44    VT           5.0
# 45    VA           5.8
# 46    WA           7.8
# 47    WV           7.5
# 48    WI           6.8
# 49    WY           5.1

# %%
import geopandas as gpd

# %%
sg_income = gpd.read_file("../data/processed/part_ii/planningarea_income_sg.shp")

sg_income.head()
# Out:
#     PLN_AREA_N PLN_AREA_C           REGION_N REGION_C  Name_x   PLN_AREA_1  \
# 0   ANG MO KIO         AM  NORTH-EAST REGION      NER  kml_19   Ang Mo Kio
# 1        BEDOK         BD        EAST REGION       ER  kml_20        Bedok
# 2       BISHAN         BS     CENTRAL REGION       CR  kml_21       Bishan
# 3     BOON LAY         BL        WEST REGION       WR  kml_22     Boon Lay
# 4  BUKIT BATOK         BK        WEST REGION       WR  kml_23  Bukit Batok
#
#    Name_y  lowinc_1k  lowinc_2k  lowinc_3k  \
# 0  kml_52   0.032053   0.118758   0.192010
# 1   kml_1   0.027287   0.092661   0.157627
# 2  kml_51   0.020294   0.059564   0.095917
# 3   kml_2   0.000000   0.000000   0.000000
# 4   kml_3   0.017531   0.086412   0.149146
#
#                                             geometry
# 0  POLYGON ((103.85721 1.39654, 103.85739 1.3963,...
# 1  POLYGON ((103.93193 1.34309, 103.9355 1.33956,...
# 2  POLYGON ((103.84924 1.36275, 103.84936 1.36268...
# 3  POLYGON ((103.69729 1.30754, 103.69728 1.30755...
# 4  POLYGON ((103.76408 1.37001, 103.76444 1.36947...

# %%
sg_income['lowinc_3k'] = sg_income['lowinc_3k'] * 100

# %%
sg_income.geometry
# Out:
# 0     POLYGON ((103.85721 1.39654, 103.85739 1.3963,...
# 1     POLYGON ((103.93193 1.34309, 103.9355 1.33956,...
# 2     POLYGON ((103.84924 1.36275, 103.84936 1.36268...
# 3     POLYGON ((103.69729 1.30754, 103.69728 1.30755...
# 4     POLYGON ((103.76408 1.37001, 103.76444 1.36947...
# 5     POLYGON ((103.8174 1.29433, 103.81743 1.29431,...
# 6     POLYGON ((103.77445 1.39029, 103.77499 1.38607...
# 7     POLYGON ((103.79766 1.34813, 103.79806 1.34779...
# 8     POLYGON ((103.90179 1.30975, 103.9015 1.30954,...
# 9     POLYGON ((103.86277 1.3303, 103.86302 1.3302, ...
# 10    POLYGON ((103.83599 1.34168, 103.83704 1.33994...
# 11    POLYGON ((103.95322 1.38202, 103.9535 1.38193,...
# 12    POLYGON ((103.88152 1.38774, 103.88269 1.38698...
# 13    MULTIPOLYGON (((103.71187 1.29861, 103.71187 1...
# 14    POLYGON ((103.72246 1.45116, 103.72426 1.45113...
# 15    POLYGON ((103.82439 1.43505, 103.82443 1.43505...
# 16    POLYGON ((103.90806 1.30982, 103.90822 1.30911...
# 17    MULTIPOLYGON (((104.05408 1.43231, 104.05431 1...
# 18    POLYGON ((103.6759 1.3305, 103.67617 1.33048, ...
# 19    POLYGON ((103.72815 1.34812, 103.72816 1.34477...
# 20    POLYGON ((103.91854 1.38129, 103.91886 1.38101...
# 21    POLYGON ((103.913 1.42004, 103.91302 1.41998, ...
# 22    POLYGON ((103.78473 1.31102, 103.78478 1.31099...
# 23    MULTIPOLYGON (((103.89715 1.41502, 103.89741 1...
# 24    POLYGON ((103.81732 1.47077, 103.81732 1.4707,...
# 25    POLYGON ((103.88791 1.40112, 103.88996 1.40088...
# 26    POLYGON ((103.88239 1.34452, 103.88272 1.34394...
# 27    POLYGON ((103.80702 1.41126, 103.80754 1.40986...
# 28    POLYGON ((103.98236 1.39356, 103.98242 1.39349...
# 29    POLYGON ((103.75819 1.44338, 103.75832 1.44338...
# 30    POLYGON ((103.97063 1.34149, 103.97067 1.34144...
# 31    POLYGON ((103.86345 1.29387, 103.86346 1.29387...
# 32    POLYGON ((103.82394 1.3004, 103.82417 1.3003, ...
# 33    POLYGON ((103.73756 1.3465, 103.73726 1.346, 1...
# 34    POLYGON ((103.84477 1.34394, 103.84508 1.34393...
# 35    POLYGON ((103.88017 1.28384, 103.88016 1.28384...
# 36    POLYGON ((103.77664 1.45145, 103.77673 1.4515,...
# 37    POLYGON ((103.86473 1.28885, 103.86909 1.28461...
# 38    POLYGON ((103.84575 1.30092, 103.84641 1.30009...
# 39    POLYGON ((103.84577 1.30984, 103.84686 1.30839...
# 40    MULTIPOLYGON (((104.02076 1.32566, 104.02139 1...
# 41    POLYGON ((103.7466 1.40541, 103.74691 1.4054, ...
# 42    POLYGON ((103.75856 1.2993, 103.75857 1.29929,...
# 43    POLYGON ((103.8341 1.29248, 103.83411 1.29247,...
# 44    MULTIPOLYGON (((103.86269 1.26976, 103.85997 1...
# 45    MULTIPOLYGON (((103.8635 1.43433, 103.86361 1....
# 46    MULTIPOLYGON (((103.82306 1.25757, 103.82306 1...
# 47    MULTIPOLYGON (((103.6392 1.35274, 103.64329 1....
# 48    MULTIPOLYGON (((103.71253 1.29163, 103.71258 1...
# 49    MULTIPOLYGON (((103.69302 1.43367, 103.69339 1...
# 50    POLYGON ((103.85563 1.42734, 103.85955 1.42552...
# 51    POLYGON ((103.83533 1.30806, 103.83538 1.30798...
# 52    POLYGON ((103.84313 1.28778, 103.84338 1.28764...
# 53    POLYGON ((103.83059 1.304, 103.83074 1.30392, ...
# 54    POLYGON ((103.85522 1.31204, 103.85541 1.31181...
# Name: geometry, dtype: geometry

# %%
# Ensure GeoDataFrame is in EPSG:4326
sg_income = sg_income.to_crs(epsg=4326)

# Create a map
m = folium.Map((1.36, 103.85), tiles="cartodb positron", zoom_start=11)

# Add Choropleth layer
folium.Choropleth(
    geo_data=sg_income,  # Ensure GeoJSON format
    name="Singapore Income in Planning Area",
    data=sg_income,
    columns=["PLN_AREA_N", "lowinc_1k"],  # Ensure these columns exist
    key_on="feature.properties.PLN_AREA_N",  # Match the property in GeoJSON
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.1,
    legend_name="Lower income (%)",
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7473f469e48dab4a2cfe7ef639837ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7473f469e48dab4a2cfe7ef639837ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7473f469e48dab4a2cfe7ef639837ff = L.map(
#                 &quot;map_c7473f469e48dab4a2cfe7ef639837ff&quot;,
#                 {
#                     center: [1.36, 103.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2e9a8971f6e1695cc50b64195b5e5c7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f2e9a8971f6e1695cc50b64195b5e5c7.addTo(map_c7473f469e48dab4a2cfe7ef639837ff);
#
#
#             var choropleth_bd097c11f6fb0d7f3b13287e0594f9f7 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;13&quot;: case &quot;16&quot;: case &quot;22&quot;: case &quot;42&quot;: case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;36&quot;: case &quot;41&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;20&quot;: case &quot;23&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;51&quot;: case &quot;53&quot;: case &quot;54&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc = L.geoJson(null, {
#                 onEachFeature: geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_onEachFeature,
#
#                 style: geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_styler,
#         });
#
#         function geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_add (data) {
#             geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc
#                 .addData(data);
#         }
#             geo_json_a2fb4b67467877ef37b6ad4ae4b0e4dc_add({&quot;bbox&quot;: [103.60570070513373, 1.1586987006352678, 104.08848306516305, 1.4707748320847587], &quot;features&quot;: [{&quot;bbox&quot;: [103.81673594941424, 1.3555123477959248, 103.8609268451811, 1.3977002304585084], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[103.85720733900295, 1.3965372889503065], [103.85739329684665, 1.3962956599721612], [103.85739545698785, 1.396291165260816], [103.857492633548, 1.3961640251487426], [103.8576637974338, 1.3956040936332508], [103.85771842436999, 1.3952999825787071], [103.85781975588156, 1.3947358672844468], [103.85795604263981, 1.3937924586338444], [103.85798492359497, 1.393592535097592], [103.8579933004458, 1.3935345444751985], [103.85800579428943, 1.3934480518728438], [103.858024417797, 1.3933191128803024], [103.85804619329059, 1.393168348837244], [103.85805796081202, 1.3927976290985211], [103.85811147784966, 1.3

# %% [markdown]
# Other powerful map visualisation tools:
#
# 1. [kepler.gl](https://kepler.gl/)
#
#     kepler gl has its Python Package: https://docs.kepler.gl/docs/keplergl-jupyter.
#
# 2. [studio.foursquare.com](https://studio.foursquare.com/)

# %% [markdown]
# ## Other major data sources in Singapore
#
# **Important Data Sources in Singapore:**
#
# 1. Data.gov.sg
#
#     [datagovsg: an unofficial Python package for interacting with APIs available at Data.gov.sg](https://datagovsg.readthedocs.io/en/latest/)
#
# 2. SingStat.gov.sg
#
#     [singstat: an unofficial Python package for interacting with APIs available at SingStat.gov.sg](https://singstat.readthedocs.io/en/latest/)
#
# 3. LTA DataMall
#
#     [landtransportsg: an unofficial Python package for interacting with APIs available at LTA DataMall](https://landtransportsg.readthedocs.io/en/latest/)
